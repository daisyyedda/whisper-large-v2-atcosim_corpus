# %%
dts = 'Jzuluaga/atcosim_corpus'
mdl = 'daisyyedda/whisper-large-v2-atcosim_corpus'
spl = 'train+test'
wsp = '-'.join(mdl.split('-')[1:])

print('Dataset: ', dts)
print('Model  : ', mdl)
print('Split  : ', spl)
print('Whisper: ', wsp)
# Out:
# Dataset:  Jzuluaga/atcosim_corpus
# Model  :  daisyyedda/whisper-large-v2-atcosim_corpus
# Split  :  train+test
# Whisper:  large-v2-atcosim_corpus

# %%
from huggingface_hub import login

login("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")
# Out:
# The token has not been saved to the git credentials helper. Pass `add_to_git_credential=True` in this function directly or `--add-to-git-credential` if using via `huggingface-cli` if you want to set the git credential as well.
# Token is valid (permission: write).
# Your token has been saved to /home/theresa_lyu/.cache/huggingface/token
# Login successful

# %%
# !pip install datasets
from datasets import load_dataset, Audio
dataset = load_dataset(dts)
dataset = dataset.cast_column("audio", Audio(sampling_rate=16000))
dataset
# Out:
# Defaulting to user installation because normal site-packages is not writeable
# Requirement already satisfied: datasets in /home/theresa_lyu/.local/lib/python3.10/site-packages (2.20.0)
# Requirement already satisfied: filelock in /home/theresa_lyu/.local/lib/python3.10/site-packages (from datasets) (3.15.1)
# Requirement already satisfied: numpy>=1.17 in /home/theresa_lyu/.local/lib/python3.10/site-packages (from datasets) (1.22.4)
# Requirement already satisfied: pyarrow>=15.0.0 in /home/theresa_lyu/.local/lib/python3.10/site-packages (from datasets) (16.1.0)
# Requirement already satisfied: pyarrow-hotfix in /home/theresa_lyu/.local/lib/python3.10/site-packages (from datasets) (0.6)
# Requirement already satisfied: dill<0.3.9,>=0.3.0 in /home/theresa_lyu/.local/lib/python3.10/site-packages (from datasets) (0.3.8)
# Requirement already satisfied: pandas in /home/theresa_lyu/.local/lib/python3.10/site-packages (from datasets) (2.2.2)
# Requirement already satisfied: requests>=2.32.2 in /home/theresa_lyu/.local/lib/python3.10/site-packages (from datasets) (2.32.3)
# Requirement already satisfied: tqdm>=4.66.3 in /home/theresa_lyu/.local/lib/python3.10/site-packages (from datasets) (4.66.4)
# Requirement already satisfied: xxhash in /home/theresa_lyu/.local/lib/python3.10/site-packages (from datasets) (3.4.1)
# Requirement already satisfied: multiprocess in /home/theresa_lyu/.local/lib/python3.10/site-packages (from datasets) (0.70.16)
# Requirement already satisfied: fsspec<=2024.5.0,>=2023.1.0 in /home/theresa_lyu/.local/lib/python3.10/site-packages (from fsspec[http]<=2024.5.0,>=2023.1.0->datasets) (2024.5.0)
# Requirement already satisfied: aiohttp in /home/theresa_lyu/.local/lib/python3.10/site-packages (from datasets) (3.9.5)
# Requirement already satisfied: huggingface-hub>=0.21.2 in /home/theresa_lyu/.local/lib/python3.10/site-packages (from datasets) (0.23.4)
# Requirement already satisfied: packaging in /home/theresa_lyu/.local/lib/python3.10/site-packages (from datasets) (24.1)
# Requirement already satisfied: pyyaml>=5.1 in /usr/lib/python3/dist-packages (from datasets) (5.4.1)
# Requirement already satisfied: aiosignal>=1.1.2 in /home/theresa_lyu/.local/lib/python3.10/site-packages (from aiohttp->datasets) (1.3.1)
# Requirement already satisfied: attrs>=17.3.0 in /usr/lib/python3/dist-packages (from aiohttp->datasets) (21.2.0)
# Requirement already satisfied: frozenlist>=1.1.1 in /home/theresa_lyu/.local/lib/python3.10/site-packages (from aiohttp->datasets) (1.4.1)
# Requirement already satisfied: multidict<7.0,>=4.5 in /home/theresa_lyu/.local/lib/python3.10/site-packages (from aiohttp->datasets) (6.0.5)
# Requirement already satisfied: yarl<2.0,>=1.0 in /home/theresa_lyu/.local/lib/python3.10/site-packages (from aiohttp->datasets) (1.9.4)
# Requirement already satisfied: async-timeout<5.0,>=4.0 in /home/theresa_lyu/.local/lib/python3.10/site-packages (from aiohttp->datasets) (4.0.3)
# Requirement already satisfied: typing-extensions>=3.7.4.3 in /home/theresa_lyu/.local/lib/python3.10/site-packages (from huggingface-hub>=0.21.2->datasets) (4.12.2)
# Requirement already satisfied: charset-normalizer<4,>=2 in /home/theresa_lyu/.local/lib/python3.10/site-packages (from requests>=2.32.2->datasets) (3.3.2)
# Requirement already satisfied: idna<4,>=2.5 in /usr/lib/python3/dist-packages (from requests>=2.32.2->datasets) (3.3)
# Requirement already satisfied: urllib3<3,>=1.21.1 in /usr/lib/python3/dist-packages (from requests>=2.32.2->datasets) (1.26.5)
# Requirement already satisfied: certifi>=2017.4.17 in /usr/lib/python3/dist-packages (from requests>=2.32.2->datasets) (2020.6.20)
# Requirement already satisfied: python-dateutil>=2.8.2 in /home/theresa_lyu/.local/lib/python3.10/site-packages (from pandas->datasets) (2.9.0.post0)
# Requirement already satisfied: pytz>=2020.1 in /home/theresa_lyu/.local/lib/python3.10/site-packages (from pandas->datasets) (2024.1)
# Requirement already satisfied: tzdata>=2022.7 in /home/theresa_lyu/.local/lib/python3.10/site-packages (from pandas->datasets) (2024.1)
# Requirement already satisfied: six>=1.5 in /home/theresa_lyu/.local/lib/python3.10/site-packages (from python-dateutil>=2.8.2->pandas->datasets) (1.16.0)
#
# [notice] A new release of pip is available: 24.1 -> 24.1.2
# [notice] To update, run: python3 -m pip install --upgrade pip
# DatasetDict({
#     train: Dataset({
#         features: ['id', 'audio', 'text', 'segment_start_time', 'segment_end_time', 'duration'],
#         num_rows: 7638
#     })
#     test: Dataset({
#         features: ['id', 'audio', 'text', 'segment_start_time', 'segment_end_time', 'duration'],
#         num_rows: 1901
#     })
# })

# %%
# Select the first 40 training examples and first 10 validation examples
dataset["train"] = dataset["train"].select(range(400))
dataset["test"] = dataset["test"].select(range(100))

# dataset should now contain 'input_features' and 'labels'
dataset
# Out:
# DatasetDict({
#     train: Dataset({
#         features: ['id', 'audio', 'text', 'segment_start_time', 'segment_end_time', 'duration'],
#         num_rows: 400
#     })
#     test: Dataset({
#         features: ['id', 'audio', 'text', 'segment_start_time', 'segment_end_time', 'duration'],
#         num_rows: 100
#     })
# })

# %%
# !pip install git+https://github.com/openai/whisper.git
import numpy as np
import pandas as pd
from datetime import datetime
import whisper

df = pd.DataFrame(columns=['split', 'hyp-prmpt', 'hyp-clean', 'ref'])

import re
import torch
import os

def hf_to_whisper_states(text):
    text = re.sub('.layers.', '.blocks.', text)
    text = re.sub('.self_attn.', '.attn.', text)
    text = re.sub('.q_proj.', '.query.', text)
    text = re.sub('.k_proj.', '.key.', text)
    text = re.sub('.v_proj.', '.value.', text)
    text = re.sub('.out_proj.', '.out.', text)
    text = re.sub('.fc1.', '.mlp.0.', text)
    text = re.sub('.fc2.', '.mlp.2.', text)
    text = re.sub('.fc3.', '.mlp.3.', text)
    text = re.sub('.fc3.', '.mlp.3.', text)
    text = re.sub('.encoder_attn.', '.cross_attn.', text)
    text = re.sub('.cross_attn.ln.', '.cross_attn_ln.', text)
    text = re.sub('.embed_positions.weight', '.positional_embedding', text)
    text = re.sub('.embed_tokens.', '.token_embedding.', text)
    text = re.sub('model.', '', text)
    text = re.sub('attn.layer_norm.', 'attn_ln.', text)
    text = re.sub('.final_layer_norm.', '.mlp_ln.', text)
    text = re.sub('encoder.layer_norm.', 'encoder.ln_post.', text)
    text = re.sub('decoder.layer_norm.', 'decoder.ln.', text)
    return text

if not os.path.exists(mdl.split('/')[-1]):
    os.system('git clone git@hf.co:'+mdl)
else:
    os.system('cd '+mdl.split('/')[-1]+' && git pull')
    os.system('cd '+mdl.split('/')[-1]+' && git lfs pull')

import torch
import requests

# URL of the model file on Hugging Face
url = "https://huggingface.co/daisyyedda/whisper-large-v2-atcosim_corpus/resolve/main/pytorch_model.bin"

# Download the file
response = requests.get(url)
with open("pytorch_model.bin", "wb") as file:
    file.write(response.content)

# Load the model
hf_state_dict = torch.load("pytorch_model.bin")
# Out:
# Defaulting to user installation because normal site-packages is not writeable
# Collecting git+https://github.com/openai/whisper.git
#   Cloning https://github.com/openai/whisper.git to /tmp/pip-req-build-dyr8t3tk
#   Running command git clone --filter=blob:none --quiet https://github.com/openai/whisper.git /tmp/pip-req-build-dyr8t3tk
#   Resolved https://github.com/openai/whisper.git to commit ba3f3cd54b0e5b8ce1ab3de13e32122d0d5f98ab
#   Installing build dependencies ... done
#   Getting requirements to build wheel ... done
#   Preparing metadata (pyproject.toml) ... done
# Requirement already satisfied: numba in /home/theresa_lyu/.local/lib/python3.10/site-packages (from openai-whisper==20231117) (0.60.0)
# Requirement already satisfied: numpy in /home/theresa_lyu/.local/lib/python3.10/site-packages (from openai-whisper==20231117) (1.22.4)
# Requirement already satisfied: torch in /home/theresa_lyu/.local/lib/python3.10/site-packages (from openai-whisper==20231117) (2.3.1+cu118)
# Requirement already satisfied: tqdm in /home/theresa_lyu/.local/lib/python3.10/site-packages (from openai-whisper==20231117) (4.66.4)
# Requirement already satisfied: more-itertools in /usr/lib/python3/dist-packages (from openai-whisper==20231117) (8.10.0)
# Requirement already satisfied: tiktoken in /home/theresa_lyu/.local/lib/python3.10/site-packages (from openai-whisper==20231117) (0.7.0)
# Requirement already satisfied: triton<3,>=2.0.0 in /home/theresa_lyu/.local/lib/python3.10/site-packages (from openai-whisper==20231117) (2.3.1)
# Requirement already satisfied: filelock in /home/theresa_lyu/.local/lib/python3.10/site-packages (from triton<3,>=2.0.0->openai-whisper==20231117) (3.15.1)
# Requirement already satisfied: llvmlite<0.44,>=0.43.0dev0 in /home/theresa_lyu/.local/lib/python3.10/site-packages (from numba->openai-whisper==20231117) (0.43.0)
# Requirement already satisfied: regex>=2022.1.18 in /home/theresa_lyu/.local/lib/python3.10/site-packages (from tiktoken->openai-whisper==20231117) (2024.5.15)
# Requirement already satisfied: requests>=2.26.0 in /home/theresa_lyu/.local/lib/python3.10/site-packages (from tiktoken->openai-whisper==20231117) (2.32.3)
# Requirement already satisfied: typing-extensions>=4.8.0 in /home/theresa_lyu/.local/lib/python3.10/site-packages (from torch->openai-whisper==20231117) (4.12.2)
# Requirement already satisfied: sympy in /home/theresa_lyu/.local/lib/python3.10/site-packages (from torch->openai-whisper==20231117) (1.12.1)
# Requirement already satisfied: networkx in /home/theresa_lyu/.local/lib/python3.10/site-packages (from torch->openai-whisper==20231117) (3.3)
# Requirement already satisfied: jinja2 in /usr/lib/python3/dist-packages (from torch->openai-whisper==20231117) (3.0.3)
# Requirement already satisfied: fsspec in /home/theresa_lyu/.local/lib/python3.10/site-packages (from torch->openai-whisper==20231117) (2024.5.0)
# Requirement already satisfied: nvidia-cuda-nvrtc-cu11==11.8.89 in /home/theresa_lyu/.local/lib/python3.10/site-packages (from torch->openai-whisper==20231117) (11.8.89)
# Requirement already satisfied: nvidia-cuda-runtime-cu11==11.8.89 in /home/theresa_lyu/.local/lib/python3.10/site-packages (from torch->openai-whisper==20231117) (11.8.89)
# Requirement already satisfied: nvidia-cuda-cupti-cu11==11.8.87 in /home/theresa_lyu/.local/lib/python3.10/site-packages (from torch->openai-whisper==20231117) (11.8.87)
# Requirement already satisfied: nvidia-cudnn-cu11==8.7.0.84 in /home/theresa_lyu/.local/lib/python3.10/site-packages (from torch->openai-whisper==20231117) (8.7.0.84)
# Requirement already satisfied: nvidia-cublas-cu11==11.11.3.6 in /home/theresa_lyu/.local/lib/python3.10/site-packages (from torch->openai-whisper==20231117) (11.11.3.6)
# Requirement already satisfied: nvidia-cufft-cu11==10.9.0.58 in /home/theresa_lyu/.local/lib/python3.10/site-packages (from torch->openai-whisper==20231117) (10.9.0.58)
# Requirement already satisfied: nvidia-curand-cu11==10.3.0.86 in /home/theresa_lyu/.local/lib/python3.10/site-packages (from torch->openai-whisper==20231117) (10.3.0.86)
# Requirement already satisfied: nvidia-cusolver-cu11==11.4.1.48 in /home/theresa_lyu/.local/lib/python3.10/site-packages (from torch->openai-whisper==20231117) (11.4.1.48)
# Requirement already satisfied: nvidia-cusparse-cu11==11.7.5.86 in /home/theresa_lyu/.local/lib/python3.10/site-packages (from torch->openai-whisper==20231117) (11.7.5.86)
# Requirement already satisfied: nvidia-nccl-cu11==2.20.5 in /home/theresa_lyu/.local/lib/python3.10/site-packages (from torch->openai-whisper==20231117) (2.20.5)
# Requirement already satisfied: nvidia-nvtx-cu11==11.8.86 in /home/theresa_lyu/.local/lib/python3.10/site-packages (from torch->openai-whisper==20231117) (11.8.86)
# Requirement already satisfied: charset-normalizer<4,>=2 in /home/theresa_lyu/.local/lib/python3.10/site-packages (from requests>=2.26.0->tiktoken->openai-whisper==20231117) (3.3.2)
# Requirement already satisfied: idna<4,>=2.5 in /usr/lib/python3/dist-packages (from requests>=2.26.0->tiktoken->openai-whisper==20231117) (3.3)
# Requirement already satisfied: urllib3<3,>=1.21.1 in /usr/lib/python3/dist-packages (from requests>=2.26.0->tiktoken->openai-whisper==20231117) (1.26.5)
# Requirement already satisfied: certifi>=2017.4.17 in /usr/lib/python3/dist-packages (from requests>=2.26.0->tiktoken->openai-whisper==20231117) (2020.6.20)
# Requirement already satisfied: mpmath<1.4.0,>=1.1.0 in /home/theresa_lyu/.local/lib/python3.10/site-packages (from sympy->torch->openai-whisper==20231117) (1.3.0)
#
# [notice] A new release of pip is available: 24.1 -> 24.1.2
# [notice] To update, run: python3 -m pip install --upgrade pip
# hint: You have divergent branches and need to specify how to reconcile them.
# hint: You can do so by running one of the following commands sometime before
# hint: your next pull:
# hint:
# hint:   git config pull.rebase false  # merge (the default strategy)
# hint:   git config pull.rebase true   # rebase
# hint:   git config pull.ff only       # fast-forward only
# hint:
# hint: You can replace "git config" with "git config --global" to set a default
# hint: preference for all repositories. You can also pass --rebase, --no-rebase,
# hint: or --ff-only on the command line to override the configured default per
# hint: invocation.
# fatal: Need to specify how to reconcile divergent branches.

# %%
# Rename layers
for key in list(hf_state_dict.keys())[:]:
    new_key = hf_to_whisper_states(key)
    hf_state_dict[new_key] = hf_state_dict.pop(key)

# Function to clean the state dictionary by removing unexpected keys
def clean_state_dict(state_dict, model):
    model_keys = set(model.state_dict().keys())
    state_dict_keys = set(state_dict.keys())
    unexpected_keys = state_dict_keys - model_keys
    print(f"Unexpected keys: {unexpected_keys}")
    for key in unexpected_keys:
        del state_dict[key]
    return state_dict
    
# Init Whisper Model and replace model weights
model = whisper.load_model('large-v2')
hf_state_dict = clean_state_dict(hf_state_dict, model)
model.load_state_dict(hf_state_dict)

# Function to filter out unexpected keys from the state dictionary
def filter_state_dict(state_dict, model):
    model_keys = set(model.state_dict().keys())
    filtered_state_dict = {k: v for k, v in state_dict.items() if k in model_keys}
    return filtered_state_dict

# Load state dictionary and filter unexpected keys
filtered_state_dict = filter_state_dict(hf_state_dict, model)
model.load_state_dict(filtered_state_dict, strict=False)

print('Starting inference...')
nato = "alpha,bravo,charlie,delta,echo,foxtrot,golf,hotel,india,juliett,kilo,lima,mike,november,oscar,papa,quebec,romeo,sierra,tango,uniform,victor,whiskey,xray,yankee,zulu"
terminology = "climb, climbing, descend, descending, passing, feet, knots, degrees, direct, maintain, identified, ILS, VFR, IFR, contact, frequency, turn, right, left, heading, altitude, flight, level, cleared, squawk, approach, runway, established, report, affirm, negative, wilco, roger, radio, radar, hold short, resume own navigation, CTR, TMA, Class A, Class B, Class C, Class D, Class E airspace, Pan-Pan, Mayday, Squawk 7700, Squawk 7600, Squawk 7500, final approach, go around, minimums, short final, line up and wait, traffic, vectors, ceiling, visibility, windshear, pushback, taxi"

for s in spl.split('+'):
    print(' ')
    for i in range(len(dataset[s])):
        audio = dataset[s][i]['audio']['array']
        audio = whisper.pad_or_trim(audio)
        if wsp == 'large-v3':
            mel = whisper.log_mel_spectrogram(np.float32(audio), n_mels=128).to(model.device)
        else:
            mel = whisper.log_mel_spectrogram(np.float32(audio)).to(model.device)

        try:
            prompt = 'Air Traffic Control Communications ' + dataset[s][i]['info'].replace('\n', ' ') + ' ' + nato.replace(',',' ') + ' ' + terminology.replace(',',' ')

        except:
            inf = ''
            prompt = 'Air Traffic Control Communications ' + nato.replace(',',' ') + ' ' + terminology.replace(',',' ')

        options = whisper.DecodingOptions(language='en', prompt=prompt, fp16=False)
        res_prmpt = whisper.decode(model, mel, options=options)
        options = whisper.DecodingOptions(language='en', fp16=False)
        res_clean = whisper.decode(model, mel, options=options)

        df.loc[len(df.index)] = [s, res_prmpt.text, res_clean.text, dataset[s][i]['text']]

        print(s, str(int(i/len(dataset[s])*100))+'%', end='\r')

df.to_excel(dts.split('/')[-1]+'-'+spl+'-'+mdl.split('/')[-1]+'-'+datetime.today().strftime('%Y-%m-%d--%H:%M:%S')+'.xlsx')

df
# Out:
# Unexpected keys: {'proj_out.weight'}
# Starting inference...
#
#  rain 99%
# test 99%
#      split                                          hyp-prmpt  \
# 0    train                Besta 810 turn right to trasadingen
# 1    train                Lufthansa 5318 contact zurich 134.6
# 2    train  base side one zero contact zurich one three th...
# 3    train             sabena four eight one rhein identified
# 4    train  transwede one zero one rhein identified set co...
# ..     ...                                                ...
# 495   test  speedbird seven seven whiskey whiskey right he...
# 496   test  luda 6 8 6 9 good morning maintain level three...
# 497   test          Lufthansa 3556 good morning radar contact
# 498   test         jet deviation 701 descent flight level 320
# 499   test  aritalia four zero one milan one three four fi...
#
#                                              hyp-clean  \
# 0                       PASA 810 turn right to Dresden
# 1                  Lufthansa 5318 contact Zurich 134.6
# 2                         D-BF810 contact Zurich 133.4
# 3               Sabena four eight one rhein identified
# 4    Run suite 101 Rhine identified set course Dras...
# ..                                                 ...
# 495  Speedbird seven seven whiskey whiskey right he...
# 496  Langen Radar 6869, good morning, maintain leve...
# 497        Lufthansa 3556, good morning, radar contact
# 498  Jet aviation seven zero one descent flight lev...
# 499                   ARITALIA 401 MILAN 13452 goodbye
#
#                                                    ref
# 0         psa eight one zero turn right to trasadingen
# 1    lufthansa five three one eight contact zurich ...
# 2    psa eight one zero contact zurich one three th...
# 3               sabena four eight one rhein identified
# 4    transwede one zero one rhein identified set co...
# ..                                                 ...
# 495  speed bird seven seven whiskey whiskey right h...
# 496  lauda six eight six nine good morning maintain...
# 497  lufthansa three five five six good morning rad...
# 498  jet aviation seven zero one descend to flight ...
# 499  alitalia four zero one milan one three four fi...
#
# [500 rows x 4 columns]

# %%
# Normalization
from Normalizer import filterAndNormalize

df['ref-norm'] = df.apply(lambda x: filterAndNormalize(x['ref']), axis=1)
df['hyp-clean-norm'] = df.apply(lambda x: filterAndNormalize(x['hyp-clean']), axis=1)
df['hyp-prmpt-norm'] = df.apply(lambda x: filterAndNormalize(x['hyp-prmpt']), axis=1)

df.head()
# Out:
#    split                                          hyp-prmpt  \
# 0  train                Besta 810 turn right to trasadingen
# 1  train                Lufthansa 5318 contact zurich 134.6
# 2  train  base side one zero contact zurich one three th...
# 3  train             sabena four eight one rhein identified
# 4  train  transwede one zero one rhein identified set co...
#
#                                            hyp-clean  \
# 0                     PASA 810 turn right to Dresden
# 1                Lufthansa 5318 contact Zurich 134.6
# 2                       D-BF810 contact Zurich 133.4
# 3             Sabena four eight one rhein identified
# 4  Run suite 101 Rhine identified set course Dras...
#
#                                                  ref  \
# 0       psa eight one zero turn right to trasadingen
# 1  lufthansa five three one eight contact zurich ...
# 2  psa eight one zero contact zurich one three th...
# 3             sabena four eight one rhein identified
# 4  transwede one zero one rhein identified set co...
#
#                                             ref-norm  \
# 0                psa 8 1 0 turn right to trasadingen
# 1           lufthansa 5 3 1 8 contact zurich 1 3 4 6
# 2                   psa 8 1 0 contact zurich 1 3 3 4
# 3                      sabena 4 8 1 rhein identified
# 4  transwede 1 0 1 rhein identified set course tr...
#
#                                       hyp-clean-norm  \
# 0                   pasa 8 1 0 turn right to dresden
# 1           lufthansa 5 3 1 8 contact zurich 1 3 4 6
# 2                   dbf 8 1 0 contact zurich 1 3 3 4
# 3                      sabena 4 8 1 rhein identified
# 4  run suite 1 0 1 rhine identified set course dr...
#
#                                       hyp-prmpt-norm
# 0              besta 8 1 0 turn right to trasadingen
# 1           lufthansa 5 3 1 8 contact zurich 1 3 4 6
# 2               base side 1 0 contact zurich 1 3 3 4
# 3                      sabena 4 8 1 rhein identified
# 4  transwede 1 0 1 rhein identified set course tr...

# %%
# WER Calculation
import jiwer

def calcWER(df, spl):
    dff = df.loc[df['split'].isin(spl.split('+'))]
    wer_cln = jiwer.wer(list(dff['ref']), list(dff['hyp-clean']))
    wer_prm = jiwer.wer(list(dff['ref']), list(dff['hyp-prmpt']))
    wer_cln_nrm = jiwer.wer(list(dff['ref-norm']), list(dff['hyp-clean-norm']))
    wer_prm_nrm = jiwer.wer(list(dff['ref-norm']), list(dff['hyp-prmpt-norm']))

    print('clean        : {} %'.format(round(wer_cln*100,4)))
    print('prmpt        : {} %'.format(round(wer_prm*100,4)))
    print('clean-norm   : {} %'.format(round(wer_cln_nrm*100,4)))
    print('prmpt-norm   : {} %'.format(round(wer_prm_nrm*100,4)))

# %%
# Split Train+Validation
spl = 'train+test'
wsp = '-'.join(mdl.split('-')[1:])

print('Dataset: ', dts)
print('Model  : ', mdl)
print('Split  : ', spl)
print('Whisper: ', wsp)

calcWER(df, spl)
# Out:
# Dataset:  Jzuluaga/atcosim_corpus
# Model  :  daisyyedda/whisper-large-v2-atcosim_corpus
# Split  :  train+test
# Whisper:  large-v2-atcosim_corpus
# clean        : 51.9557 %
# prmpt        : 27.2085 %
# clean-norm   : 16.6278 %
# prmpt-norm   : 11.6686 %

# %%
# Split Validation
spl = 'test'
wsp = '-'.join(mdl.split('-')[1:])

print('Dataset: ', dts)
print('Model  : ', mdl)
print('Split  : ', spl)
print('Whisper: ', wsp)

calcWER(df, spl)
# Out:
# Dataset:  Jzuluaga/atcosim_corpus
# Model  :  daisyyedda/whisper-large-v2-atcosim_corpus
# Split  :  test
# Whisper:  large-v2-atcosim_corpus
# clean        : 53.7313 %
# prmpt        : 34.7948 %
# clean-norm   : 14.7004 %
# prmpt-norm   : 11.7041 %
